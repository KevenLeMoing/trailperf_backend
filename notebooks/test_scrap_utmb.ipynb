# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
response = requests.get('https://utmbmontblanc.com/result.php?mode=edPass&ajax=true&annee=2018&course=utmb')

# %%
response.text
# Out:
# u'<h2>Results of a race</h2>\n    <script type="text/javascript">\n      function getDet(dossard) {\n        popInUrl("/result.php","mode=detail&annee=2018&dossard="+dossard+"&course=utmb", "Dossard "+dossard+" - UTMB\xae 2018");\n      }\n      $(function() {\n\t$("#tab").on("scroll", scroll);\n\t});\n    </script>\n          <script type="text/javascript" src="/tableau.js"></script>\r\n      <script>\r\n        $(document).ready(function(){\r\n          $("div.thead table").html($("#tabPass thead"));\r\n          $("#tabPass thead").remove();\r\n          setTimeout(function(){\r\n            $("div.thead table thead th").each(function(i){\r\n              $(this).css("width", $("#tabPass tbody td").eq(i).css("width"));\r\n            });\r\n          }, 200);\r\n\r\n          $("#tabPass").parent().scroll(function(){\r\n            $("div.thead")\r\n              .prop("scrollLeft", this.scrollLeft);\r\n          });\r\n        });\r\n      </script>\r\n      <h3>Time charts - UTMB\xae 2018</h3>\r\n      \n      <form name="F1" class="fretour" method="POST">\n                  <input type="submit" class="bouton_bleu" value="Return" onclick="$(\'.results\').toggle();$(\'#resultats\').html(\'\');return false;"/>\n              </form><br/>\n      <div class="thead" style="overflow-x:hidden;overflow-y:hidden;"><table style="table-layout: fixed;" class="respTable noOddBckgrnd"></table></div>\n      <div style="width: 100%;height:40em;overflow-x:scroll;overflow-y:auto;">\n        <table id="tabPass" class="respTable">\n          <thead>\n            <tr>\n              <th>Pos.</th>\n              <th>Dos.</th>\n              <th>Nom Prenom</th>\n              <th>Cat</th>\n                              <th>Delevret</th>\n                              <th>St-Gervais</th>\n                              <th>Contamines</th>\n                              <th>La Balme</th>\n                              <th>Bonhomme</th>\n                              <th>Chapieux</th>\n                              <th>Col Seigne</th>\n                              <th>Lac Combal</th>\n                              <th>Mt-Favre</th>\n                              <th>Checrouit</th>\n                              <th>Courmayeur</th>\n                              <th>P.Ange</th>\n                              <th>Bertone</th>\n                              <th>Bonatti</th>\n                              <th>Arnouvaz</th>\n                              <th>Col Ferret</th>\n                              <th>La Peule</th>\n                              <th>La Fouly</th>\n                              <th>Champex</th>\n                              <th>La Gi\xe8te</th>\n                              <th>Trient</th>\n                              <th>Tseppes</th>\n                              <th>Vallorcine</th>\n                              <th>TreLeChamp</th>\n                              <th>La Fl\xe9g\xe8re</th>\n                              <th>Chamonix</th>\n                          </tr>\n          </thead>\n          <!-- style="display:block;overflow-x:scroll;overflow-y:scroll;height:38em;" -->\n          <tbody>\n                          <tr class="l1">\n                <td class="r" style="height:32px">1</td>\n                <td class="r">\n                  <a href="javascript:getDet(\'9\')">9</a>\n                </td>\n                <td>\n                  <div class="c">THEVENARD Xavier</div>\n                </td>\n                <td nowrap="nowrap">SE H</td>\n                <td>01:13:48</td><td>01:47:32</td><td>02:43:24</td><td>03:39:51</td><td>04:40:22</td><td>05:07:26</td><td>06:40:20</td><td>07:02:09</td><td>07:44:11</td><td>08:08:59</td><td>08:33:40</td><td>08:43:25</td><td>09:38:10</td><td>10:31:05</td><td>11:07:25</td><td>12:09:02</td><td>12:30:00</td><td>13:05:40</td><td>14:34:41</td><td>16:12:53</td><td>16:42:51</td><td>17:31:24</td><td>18:17:04</td><td>18:46:59</td><td>20:02:45</td><td>20:44:16</td>              </tr> ...

# %%
res = requests.get("https://utmbmontblanc.com/result.php?mode=edPass&ajax=true&annee=2018&course=utmb")
soup = BeautifulSoup(res.content,'html.parser')

# %%
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <h2>Results of a race</h2>\n<script type="text/javascript">\n      function getDet(dossard) {\n        popInUrl("/result.php","mode=detail&annee=2018&dossard="+dossard+"&course=utmb", "Dossard "+dossard+" - UTMB\xae 2018");\n      }\n      $(function() {\n\t$("#tab").on("scroll", scroll);\n\t});\n    </script>\n<script src="/tableau.js" type="text/javascript"></script>\n<script>\r\n        $(document).ready(function(){\r\n          $("div.thead table").html($("#tabPass thead"));\r\n          $("#tabPass thead").remove();\r\n          setTimeout(function(){\r\n            $("div.thead table thead th").each(function(i){\r\n              $(this).css("width", $("#tabPass tbody td").eq(i).css("width"));\r\n            });\r\n          }, 200);\r\n\r\n          $("#tabPass").parent().scroll(function(){\r\n            $("div.thead")\r\n              .prop("scrollLeft", this.scrollLeft);\r\n          });\r\n        });\r\n      </script>\n<h3>Time charts - UTMB\xae 2018</h3>\n<form class="fretour" method="POST" name="F1">\n<input class="bouton_bleu" onclick="$('.results').toggle();$('#resultats').html('');return false;" type="submit" value="Return"/>\n</form><br/>\n<div class="thead" style="overflow-x:hidden;overflow-y:hidden;"><table class="respTable noOddBckgrnd" style="table-layout: fixed;"></table></div>\n<div style="width: 100%;height:40em;overflow-x:scroll;overflow-y:auto;">\n<table class="respTable" id="tabPass">\n<thead>\n<tr>\n<th>Pos.</th>\n<th>Dos.</th>\n<th>Nom Prenom</th>\n<th>Cat</th>\n<th>Delevret</th>\n<th>St-Gervais</th>\n<th>Contamines</th>\n<th>La Balme</th>\n<th>Bonhomme</th>\n<th>Chapieux</th>\n<th>Col Seigne</th>\n<th>Lac Combal</th>\n<th>Mt-Favre</th>\n<th>Checrouit</th>\n<th>Courmayeur</th>\n<th>P.Ange